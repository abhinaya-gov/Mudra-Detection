# %%
from ultralytics import YOLO
import cv2
import torch
import torch.nn as nn
import torchvision.transforms as T
from PIL import Image

# %%
# ===========================================================
# 1. DEFINE YOUR MUDRA MODEL (same architecture you trained)
# ===========================================================

class MudraCNN(nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        def block(inp, out):
            return nn.Sequential(
                nn.Conv2d(inp, out, 3, padding=1),
                nn.ReLU(),
                nn.BatchNorm2d(out),
                nn.Conv2d(out, out, 3, padding=1),
                nn.ReLU(),
                nn.BatchNorm2d(out)
            )

        self.net = nn.Sequential(
            block(3, 32),
            nn.MaxPool2d(2),

            block(32, 64),
            nn.MaxPool2d(2),

            block(64, 128),
            nn.MaxPool2d(3),

            block(128, 256),
            nn.MaxPool2d(3),

            block(256, 256),
            nn.MaxPool2d(3),
        )
        self.fc = nn.Linear(256*3*3, num_classes)

    def forward(self, x):
        x = self.net(x)
        x = x.view(x.size(0), -1)
        return self.fc(x)


# ===========================================================
# 2. LOAD YOUR TRAINED CLASSIFIER
# ===========================================================

def load_mudra_model(path="/mudra_project/hand_model_mudra_green_10_me.pth"):
    checkpoint = torch.load(path, map_location="cpu")
    classes = checkpoint["classes"]

    model = MudraCNN(num_classes=len(classes))
    model.load_state_dict(checkpoint["state_dict"])
    model.eval()

    device = "mps" if torch.backends.mps.is_available() else "cpu"
    model.to(device)

    return model, classes, device


# Preprocessing for classifier
transform = T.Compose([
    T.ToPILImage(),
    T.Resize((416, 416)),
    T.ToTensor()
])


@torch.no_grad()
def classify_hand(model, classes, device, crop_bgr):
    crop_rgb = cv2.cvtColor(crop_bgr, cv2.COLOR_BGR2RGB)
    img = transform(crop_rgb).unsqueeze(0).to(device)

    logits = model(img)
    probs = torch.softmax(logits, dim=1)[0]

    conf, idx = torch.max(probs, dim=0)
    return classes[idx.item()], float(conf)


# ===========================================================
# 3. MAIN PIPELINE — DETECTION + CLASSIFICATION
# ===========================================================

def main():

    # ---- Load YOLO ----
    yolo_model_path = "/Users/abhin-zstch1563/Documents/AI/DL/CNN/mudra_project/weights 13-12-2025 16_20_40_118/best.pt"
    yolo = YOLO(yolo_model_path)
    print("Loaded YOLO model")

    # ---- Load Mudra Classifier ----
    mudra_model, classes, device = load_mudra_model()
    print("Loaded Mudra classifier")

    # ---- Open Camera ----
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        print("Camera error")
        return

    print("Press 'q' to quit")

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Run YOLO
        results = yolo(frame, stream=True, conf=0.5)

        # Process detections
        for result in results:
            for box in result.boxes:

                # YOLO bounding box
                x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)

                # Safely crop the hand region
                h, w, _ = frame.shape
                x1, y1 = max(0, x1), max(0, y1)
                x2, y2 = min(w, x2), min(h, y2)

                crop = frame[y1:y2, x1:x2]
                if crop.size == 0:
                    continue

                # ---- CLASSIFY THE CROPPED HAND ----
                label, conf = classify_hand(
                    mudra_model, classes, device, crop
                )

                # # Draw YOLO box
                # cv2.rectangle(frame, (x1, y1), (x2, y2),
                #               (0, 255, 0), 2)

                # Draw mudra label
                text = f"{label} ({conf:.2f})"
                cv2.putText(frame, text, (70, 50),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            1.0, (0, 200, 100), 2)

        # Show output
        cv2.imshow("Hand Detection + Mudra Classification", frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()


if __name__ == "__main__":
    main()
# Out:
# Loaded YOLO model
# Loaded Mudra classifier
# Press 'q' to quit
#
# 0: 256x416 (no detections), 14.8ms
# Speed: 1.0ms preprocess, 14.8ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 24.2ms
# Speed: 1.8ms preprocess, 24.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 14
5ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 16.1ms
# Speed: 0.7ms preprocess, 16.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 16.7ms
# Speed: 0.6ms preprocess, 16.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 15.3ms
# Speed: 0.6ms preprocess, 15.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 16.1ms
# Speed: 0.9ms preprocess, 16.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 16.4ms
# Speed: 0.6ms preprocess, 16.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 14.9ms
# Speed: 0.6ms preprocess, 14.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 14.8ms
# Speed: 0.5ms preprocess, 14.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 15.2ms
# Speed: 0.6ms preprocess, 15.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 15.1ms
# Speed: 0.7ms preprocess, 15.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.0ms
# Speed: 0.6ms preprocess, 16.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 15.8ms
# Speed: 0.7ms preprocess, 15.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.5ms
# Speed: 0.6ms preprocess, 16.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.4ms
# Speed: 0.8ms preprocess, 16.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.6ms
# Speed: 0.7ms preprocess, 16.6ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 15.2ms
# Speed: 0.7ms preprocess, 15.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.3ms
# Speed: 0.6ms preprocess, 16.3ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 15.8ms
# Speed: 0.7ms preprocess, 15.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.7ms
# Speed: 1.0ms preprocess, 16.7ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.8ms
# Speed: 0.6ms preprocess, 16.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.0ms
# Speed: 0.9ms preprocess, 16.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.7ms
# Speed: 0.7ms preprocess, 16.7ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.7ms
# Speed: 0.7ms preprocess, 16.7ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 17.8ms
# Speed: 0.6ms preprocess, 17.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 17.5ms
# Speed: 0.6ms preprocess, 17.5ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 17.3ms
# Speed: 0.6ms preprocess, 17.3ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 15.0ms
# Speed: 0.6ms preprocess, 15.0ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.9ms
# Speed: 0.8ms preprocess, 16.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 17.0ms
# Speed: 0.7ms preprocess, 17.0ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 17.0ms
# Speed: 0.7ms preprocess, 17.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.8ms
# Speed: 0.6ms preprocess, 16.8ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.3ms
# Speed: 0.6ms preprocess, 16.3ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.5ms
# Speed: 0.7ms preprocess, 16.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.9ms
# Speed: 0.6ms preprocess, 16.9ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 14.1ms
# Speed: 0.6ms preprocess, 14.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 14.2ms
# Speed: 1.0ms preprocess, 14.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 13.3ms
# Speed: 0.6ms preprocess, 13.3ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 14.4ms
# Speed: 0.6ms preprocess, 14.4ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 13.0ms
# Speed: 0.7ms preprocess, 13.0ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 13.8ms
# Speed: 0.6ms preprocess, 13.8ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 13.5ms
# Speed: 0.6ms preprocess, 13.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 15.0ms
# Speed: 0.8ms preprocess, 15.0ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 15.6ms
# Speed: 0.7ms preprocess, 15.6ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.9ms
# Speed: 0.9ms preprocess, 16.9ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 17.0ms
# Speed: 0.8ms preprocess, 17.0ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 16.1ms
# Speed: 0.8ms preprocess, 16.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 15.2ms
# Speed: 0.8ms preprocess, 15.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 16.4ms
# Speed: 0.7ms preprocess, 16.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 16.7ms
# Speed: 0.8ms preprocess, 16.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 16.7ms
# Speed: 1.0ms preprocess, 16.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 17.3ms
# Speed: 0.8ms preprocess, 17.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 16.8ms
# Speed: 0.8ms preprocess, 16.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 16.4ms
# Speed: 1.0ms preprocess, 16.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 15.4ms
# Speed: 1.0ms preprocess, 15.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 16.7ms
# Speed: 0.6ms preprocess, 16.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 14.1ms
# Speed: 0.8ms preprocess, 14.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 14.2ms
# Speed: 0.7ms preprocess, 14.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 15.3ms
# Speed: 0.6ms preprocess, 15.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 16.1ms
# Speed: 0.6ms preprocess, 16.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 15.9ms
# Speed: 0.8ms preprocess, 15.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 17.5ms
# Speed: 1.0ms preprocess, 17.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 15.4ms
# Speed: 0.8ms preprocess, 15.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 2 hands, 17.0ms
# Speed: 0.6ms preprocess, 17.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 15.1ms
# Speed: 0.6ms preprocess, 15.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 16.7ms
# Speed: 0.7ms preprocess, 16.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 15.3ms
# Speed: 0.7ms preprocess, 15.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 16.2ms
# Speed: 0.6ms preprocess, 16.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 15.1ms
# Speed: 0.9ms preprocess, 15.1ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 16.1ms
# Speed: 0.8ms preprocess, 16.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.7ms
# Speed: 0.7ms preprocess, 16.7ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 16.3ms
# Speed: 0.9ms preprocess, 16.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 15.5ms
# Speed: 0.6ms preprocess, 15.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 13.6ms
# Speed: 0.8ms preprocess, 13.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 14.7ms
# Speed: 0.6ms preprocess, 14.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 14.8ms
# Speed: 0.7ms preprocess, 14.8ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 15.6ms
# Speed: 0.6ms preprocess, 15.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.6ms
# Speed: 0.8ms preprocess, 16.6ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 15.9ms
# Speed: 0.6ms preprocess, 15.9ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 16.2ms
# Speed: 0.7ms preprocess, 16.2ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 15.5ms
# Speed: 0.8ms preprocess, 15.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 13.9ms
# Speed: 0.7ms preprocess, 13.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 15.8ms
# Speed: 1.0ms preprocess, 15.8ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 15.2ms
# Speed: 0.5ms preprocess, 15.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 1 hand, 14.4ms
# Speed: 0.7ms preprocess, 14.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 416)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
